# %%
#UPDATED version of the check_logfile for behavioural analysis.
import pandas as pd
import pickle
import numpy as np
#import matplotlib.pyplot as plt

# %%
#unpickling the pickle file. The pickle file is created from the logfile of the experiment
unpickled_df = pd.read_pickle("/Users/nestor/Documents/Marburg/FRAPPS/logfiles/FaceID/logfile_s001.pkl")
unpickled_df
# Out:
# {'subjectID': 's001',
#  'onset': ['8.27744667877414',
#   '17.564290209964383',
#   '19.56922333863622',
#   '19.56924628061097',
#   '19.836594263601',
#   '22.878766446156078',
#   '30.39556857613934',
#   '31.30435157975444',
#   '31.3043875020594',
#   '31.56766117116058',
#   '34.84380921332195',
#   '42.875296472222544',
#   '44.134151395919616',
#   '44.134190336902975',
#   '44.39058231867966',
#   '47.41717237122066',
#   '56.1818981768738',
#   '56.96488730509009',
#   '56.96492534047138',
#   '57.229184307085234',
#   '60.00612550770893',
#   '65.27650062411703',
#   '66.45974875517277',
#   '66.45978679055406',
#   '66.7136946996543',
#   '73.73385798011441',
#   '79.00426267959847',
#   '80.21145921535935',
#   '80.21149755260558',
#   '80.47278674074914',
#   '86.99364748747757',
#   '90.0177290160209',
#   '90.61629453875503',
#   '90.61633257413632',
#   '90.877779337432',
#   '99.14589104674815',
#   '104.41619311107206',
#   '105.13907094051683',
# ...

# %%
data = unpickled_df
del data['subjectID'] #deleting some unnecessary info
del data['answers order']

# %%
df = pd.DataFrame.from_dict(data)

# %%
pd.set_option('display.max_rows', None)
df.head()
# Out:
#                 onset                                             event
# 0    8.27744667877414                                              081f
# 1  17.564290209964383      Haben Sie diese Person schon einmal gesehen?
# 2   19.56922333863622                                button not pressed
# 3   19.56924628061097  None [left click=yes right click=no None=missed]
# 4     19.836594263601                                    0 missed trial

# %%
#df.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\behv_data\\out\\sub-001\\DataFrame_OnsetsNallevents.csv")

# %%
OnstsNfacs = df.iloc[::5, :]

# %%
OnstsNfacs
# Out:
#                   onset event
# 0      8.27744667877414  081f
# 5    22.878766446156078  181r
# 10    34.84380921332195  181l
# 15    47.41717237122066  071l
# 20    60.00612550770893  181l
# ..                  ...   ...
# 920  2256.6818699522046  198l
# 925   2271.002437283132  198f
# 930  2282.4058480909152  211l
# 935   2295.681168410716  211f
# 940   2306.445004007299  211f
#
# [189 rows x 2 columns]

# %%
df["event"].shape
# Out:
# (945,)

# %%
OnstsNfacs.rename(columns={"event" : "Faces"})
# Out:
#                   onset Faces
# 0      8.27744667877414  081f
# 5    22.878766446156078  181r
# 10    34.84380921332195  181l
# 15    47.41717237122066  071l
# 20    60.00612550770893  181l
# ..                  ...   ...
# 920  2256.6818699522046  198l
# 925   2271.002437283132  198f
# 930  2282.4058480909152  211l
# 935   2295.681168410716  211f
# 940   2306.445004007299  211f
#
# [189 rows x 2 columns]

# %%
OnstsNfacs.to_csv("/Users/nestor/Documents/Marburg/FRAPPS/logfiles/FaceID/sub-001_DataFrame_OnstsNFacs.csv")

# %%
QuestionOnsets = df[df.index % 5 == 1]

# %%
QuestionOnsets
# Out:
#                   onset                                         event
# 1    17.564290209964383  Haben Sie diese Person schon einmal gesehen?
# 6     30.39556857613934  Haben Sie diese Person schon einmal gesehen?
# 11   42.875296472222544  Haben Sie diese Person schon einmal gesehen?
# 16     56.1818981768738  Haben Sie diese Person schon einmal gesehen?
# 21    65.27650062411703  Haben Sie diese Person schon einmal gesehen?
# ..                  ...                                           ...
# 921  2261.9526181775946  Haben Sie diese Person schon einmal gesehen?
# 926  2273.2779837021444  Haben Sie diese Person schon einmal gesehen?
# 931  2288.4253563175735  Haben Sie diese Person schon einmal gesehen?
# 936  2300.4526950030267  Haben Sie diese Person schon einmal gesehen?
# 941   2313.462855279904  Haben Sie diese Person schon einmal gesehen?
#
# [189 rows x 2 columns]

# %%
QuestionOnsets.rename(columns={"event" : "Questions"})
QuestionOnsets.to_csv("/Users/nestor/Documents/Marburg/FRAPPS/logfiles/FaceID/sub-001_DataFrame_OnstsNFacs.csv")

# %%
#get onset of button press from dataframe
BttnPrss = df[df.index % 5 == 2]
BttnPrss.head()
# Out:
#                  onset                event
# 2    19.56922333863622   button not pressed
# 7    31.30435157975444     b button pressed
# 12  44.134151395919616     b button pressed
# 17   56.96488730509009     a button pressed
# 22   66.45974875517277     a button pressed

# %%
BttnPrssnOnsets = BttnPrss[['onset']]
BttnPrssnOnsets.rename(columns={"onset" : "ButtonPress"})
BttnPrssnOnsets.head()
# Out:
#                   onset
# 2     19.56922333863622
# 7     31.30435157975444
# 12   44.134151395919616
# 17    56.96488730509009
# 22    66.45974875517277
# 27    80.21145921535935
# 32    90.61629453875503
# 37   105.13907094051683
# 42   115.26082461312035
# 47   127.98164762633678
# 52   138.01942008117476
# 57   150.40618346638803
# 62   162.57494434306864
# 67   177.19472757157928
# 72   186.20957646395254
# 77   200.03131942023174
# 82   212.08408506039996
# 87    222.3248577823906
# 92   234.63064504687645
# 97   251.02935637190967
# 102  261.11018669033365
# 107   270.9789706599331
# 112  288.18267941154045
# 117   296.7135627832904
# 122   312.5292037775798
# 127  323.15103518122487
# 132   334.6028614078241
# 137   346.9286347561938
# 142  358.72877029497613
# 147   370.7491397513513
# 152  386.44787296182767
# 157   395.1397096934379
# 162  409.92945795052947
# 167  420.46028426920384
# 172  432.75703933794284
# 177   443.7527205108854
# 182  455.36361402540206
# ...

# %%
Evnts = df[["event"]]

# %%
BttnPrssnOnsets = df[df.index % 5 == 1]
BttnPrssnOnsets
# Out:
#                   onset                                         event
# 1    17.564290209964383  Haben Sie diese Person schon einmal gesehen?
# 6     30.39556857613934  Haben Sie diese Person schon einmal gesehen?
# 11   42.875296472222544  Haben Sie diese Person schon einmal gesehen?
# 16     56.1818981768738  Haben Sie diese Person schon einmal gesehen?
# 21    65.27650062411703  Haben Sie diese Person schon einmal gesehen?
# ..                  ...                                           ...
# 921  2261.9526181775946  Haben Sie diese Person schon einmal gesehen?
# 926  2273.2779837021444  Haben Sie diese Person schon einmal gesehen?
# 931  2288.4253563175735  Haben Sie diese Person schon einmal gesehen?
# 936  2300.4526950030267  Haben Sie diese Person schon einmal gesehen?
# 941   2313.462855279904  Haben Sie diese Person schon einmal gesehen?
#
# [189 rows x 2 columns]

# %%
Evnts.head()
# Out:
#                                        event
# 0                                       158l
# 1                           8 button pressed
# 2  1 [NO] [correctly identified as new face]
# 3                                       071r
# 4                           8 button pressed

# %%
TrialShape = Evnts.iloc[0:3]

# %%
TrialShape
# Out:
#                                        event
# 0                                       158l
# 1                           8 button pressed
# 2  1 [NO] [correctly identified as new face]

# %%
FcsPresented = Evnts.iloc[::3, :]

# %%
FcsPresented.shape
# Out:
# (189, 1)

# %%
FcsPresented.rename(columns={"event" : "Faces"})
# Out:
#     Faces
# 0    158l
# 3    071r
# 6    071l
# 9    008f
# 12   071r
# 15   071f
# 18   071l
# 21   007r
# 24   007r
# 27   008r
# 30   007r
# 33   045l
# 36   158r
# 39   205l
# 42   045f
# 45   071f
# 48   205l
# 51   158r
# 54   205f
# 57   008r
# 60   008l
# 63   071r
# 66   071f
# 69   008r
# 72   007f
# 75   045f
# 78   007l
# 81   158r
# 84   158f
# 87   008l
# ..    ...
# 477  081l
# 480  294r
# 483  070f
# 486  260f
# 489  150f
# 492  162l
# 495  150l
# 498  081r
# 501  201f
# 504  150l
# 507  081f
# 510  039r
# 513  070f
# 516  039r
# 519  070l
# 522  153l
# 525  081f
# 528  150r
# 531  070f
# 534  162l
# 537  162f
# 540  150r
# 543  039r
# 546  162l
# 549  162r
# 552  162f
# 555  162r
# 558  153r
# 561  153r
# 564  153r
#
# [189 rows x 1 columns]

# %%
FP= FcsPresented.reset_index()

# %%
FP.rename(columns={"event" : "Faces"})
# Out:
#      index Faces
# 0        0  158l
# 1        3  071r
# 2        6  071l
# 3        9  008f
# 4       12  071r
# 5       15  071f
# 6       18  071l
# 7       21  007r
# 8       24  007r
# 9       27  008r
# 10      30  007r
# 11      33  045l
# 12      36  158r
# 13      39  205l
# 14      42  045f
# 15      45  071f
# 16      48  205l
# 17      51  158r
# 18      54  205f
# 19      57  008r
# 20      60  008l
# 21      63  071r
# 22      66  071f
# 23      69  008r
# 24      72  007f
# 25      75  045f
# 26      78  007l
# 27      81  158r
# 28      84  158f
# 29      87  008l
# ..     ...   ...
# 159    477  081l
# 160    480  294r
# 161    483  070f
# 162    486  260f
# 163    489  150f
# 164    492  162l
# 165    495  150l
# 166    498  081r
# 167    501  201f
# 168    504  150l
# 169    507  081f
# 170    510  039r
# 171    513  070f
# 172    516  039r
# 173    519  070l
# 174    522  153l
# 175    525  081f
# 176    528  150r
# 177    531  070f
# 178    534  162l
# ...

# %%
BttnPrss = Evnts[Evnts.index % 3 == 1]

# %%
BttnPrss
# Out:
#                    event
# 1       8 button pressed
# 4       8 button pressed
# 7       7 button pressed
# 10      8 button pressed
# 13      7 button pressed
# 16      7 button pressed
# 19      7 button pressed
# 22      8 button pressed
# 25      7 button pressed
# 28      8 button pressed
# 31      7 button pressed
# 34      8 button pressed
# 37      8 button pressed
# 40      7 button pressed
# 43      7 button pressed
# 46      7 button pressed
# 49      7 button pressed
# 52      8 button pressed
# 55      7 button pressed
# 58      7 button pressed
# 61      7 button pressed
# 64      7 button pressed
# 67      7 button pressed
# 70      7 button pressed
# 73      7 button pressed
# 76      8 button pressed
# 79      7 button pressed
# 82      8 button pressed
# 85      8 button pressed
# 88      7 button pressed
# ..                   ...
# 478     7 button pressed
# 481     7 button pressed
# 484     7 button pressed
# 487     8 button pressed
# 490     7 button pressed
# ...

# %%
BttnPrss.shape
# Out:
# (189, 1)

# %%
BP = BttnPrss.reset_index()

# %%
BP.rename(columns={"event" : "Button"}) # In scanner 7 is left and 8 is right
# Out:
#      index               Button
# 0        1     8 button pressed
# 1        4     8 button pressed
# 2        7     7 button pressed
# 3       10     8 button pressed
# 4       13     7 button pressed
# 5       16     7 button pressed
# 6       19     7 button pressed
# 7       22     8 button pressed
# 8       25     7 button pressed
# 9       28     8 button pressed
# 10      31     7 button pressed
# 11      34     8 button pressed
# 12      37     8 button pressed
# 13      40     7 button pressed
# 14      43     7 button pressed
# 15      46     7 button pressed
# 16      49     7 button pressed
# 17      52     8 button pressed
# 18      55     7 button pressed
# 19      58     7 button pressed
# 20      61     7 button pressed
# 21      64     7 button pressed
# 22      67     7 button pressed
# 23      70     7 button pressed
# 24      73     7 button pressed
# 25      76     8 button pressed
# 26      79     7 button pressed
# 27      82     8 button pressed
# ...

# %%
Answrs =  Evnts[Evnts.index % 3 == 2]

# %%
Answrs.shape
# Out:
# (189, 1)

# %%
Answrs
# Out:
#                                          event
# 2    1 [NO] [correctly identified as new face]
# 5    1 [NO] [correctly identified as new face]
# 8               1 [YES] [correctly remembered]
# 11   1 [NO] [correctly identified as new face]
# 14              1 [YES] [correctly remembered]
# 17              1 [YES] [correctly remembered]
# 20              1 [YES] [correctly remembered]
# 23   1 [NO] [correctly identified as new face]
# 26              1 [YES] [correctly remembered]
# 29                 0 [NO][face not remembered]
# 32              1 [YES] [correctly remembered]
# 35   1 [NO] [correctly identified as new face]
# 38                 0 [NO][face not remembered]
# 41     0 [YES][WRONG:falsely remembered- FNSB]
# 44              1 [YES] [correctly remembered]
# 47              1 [YES] [correctly remembered]
# 50              1 [YES] [correctly remembered]
# 53                 0 [NO][face not remembered]
# 56              1 [YES] [correctly remembered]
# ...

# %%
Ans=Answrs.reset_index()

# %%
Ans = Ans.rename(columns={"event" : "Answer"})

# %%
Ans.shape
# Out:
# (189, 2)

# %%
Ans = Ans.drop(Ans.columns[[0]], axis =1)

# %%
Ans
# Out:
#                                         Answer
# 0    1 [NO] [correctly identified as new face]
# 1    1 [NO] [correctly identified as new face]
# 2               1 [YES] [correctly remembered]
# 3    1 [NO] [correctly identified as new face]
# 4               1 [YES] [correctly remembered]
# 5               1 [YES] [correctly remembered]
# 6               1 [YES] [correctly remembered]
# 7    1 [NO] [correctly identified as new face]
# 8               1 [YES] [correctly remembered]
# 9                  0 [NO][face not remembered]
# 10              1 [YES] [correctly remembered]
# 11   1 [NO] [correctly identified as new face]
# 12                 0 [NO][face not remembered]
# 13     0 [YES][WRONG:falsely remembered- FNSB]
# 14              1 [YES] [correctly remembered]
# 15              1 [YES] [correctly remembered]
# 16              1 [YES] [correctly remembered]
# 17                 0 [NO][face not remembered]
# 18              1 [YES] [correctly remembered]
# ...

# %%
FBA =  pd.concat([FP, BP, Ans], axis = 1, ignore_index='True')

# %%
FBA
# Out:
#        0     1    2                    3  \
# 0      0  158l    1     8 button pressed
# 1      3  071r    4     8 button pressed
# 2      6  071l    7     7 button pressed
# 3      9  008f   10     8 button pressed
# 4     12  071r   13     7 button pressed
# 5     15  071f   16     7 button pressed
# 6     18  071l   19     7 button pressed
# 7     21  007r   22     8 button pressed
# 8     24  007r   25     7 button pressed
# 9     27  008r   28     8 button pressed
# 10    30  007r   31     7 button pressed
# 11    33  045l   34     8 button pressed
# 12    36  158r   37     8 button pressed
# 13    39  205l   40     7 button pressed
# 14    42  045f   43     7 button pressed
# 15    45  071f   46     7 button pressed
# 16    48  205l   49     7 button pressed
# 17    51  158r   52     8 button pressed
# 18    54  205f   55     7 button pressed
# 19    57  008r   58     7 button pressed
# 20    60  008l   61     7 button pressed
# 21    63  071r   64     7 button pressed
# ...

# %%
df_FBA = FBA.drop(FBA.columns[[0, 2,]], axis=1) #rs(reshaped Face Button Answer datefr)

# %%
df_FBA = df_FBA.rename(columns={1:'Faces', 3:'Button', 4:'Answer'})

# %%
df_FBA
# Out:
#     Faces               Button                                     Answer
# 0    158l     8 button pressed  1 [NO] [correctly identified as new face]
# 1    071r     8 button pressed  1 [NO] [correctly identified as new face]
# 2    071l     7 button pressed             1 [YES] [correctly remembered]
# 3    008f     8 button pressed  1 [NO] [correctly identified as new face]
# 4    071r     7 button pressed             1 [YES] [correctly remembered]
# 5    071f     7 button pressed             1 [YES] [correctly remembered]
# 6    071l     7 button pressed             1 [YES] [correctly remembered]
# 7    007r     8 button pressed  1 [NO] [correctly identified as new face]
# 8    007r     7 button pressed             1 [YES] [correctly remembered]
# 9    008r     8 button pressed                0 [NO][face not remembered]
# 10   007r     7 button pressed             1 [YES] [correctly remembered]
# 11   045l     8 button pressed  1 [NO] [correctly identified as new face]
# ...

# %%
df_FBA.to_csv("\\Users\\Nestor\\Desktop\\FRAPPS\\behv_data\\out\\sub-003\\Face_Bttn_Ans.csv")

# %%
CINFs_only_Answrs = (Ans.loc[Ans['Answer'] == '1 [NO] [correctly identified as new face]']) #1 [NO] [correctly identified as new face] new version of the script

# %%
CINFs_only_Answrs.shape
# Out:
# (22, 1)

# %%
num_of_no1 = CINFs_only_Answrs.shape
num_of_no1
# Out:
# (22, 1)

# %%
#CINFs_only_Answrs.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\CINFs.csv")

# %%
FsNR_only_Answrs = (Ans.loc[Ans['Answer'] == '0 [NO][face not remembered]']) #0 [NO] [face not remembered]

# %%
FsNR_only_Answrs.shape
# Out:
# (22, 1)

# %%
num_of_no2 = FsNR_only_Answrs.shape 
num_of_no2
# Out:
# (22, 1)

# %%
#FsNR_only_Answrs.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\FsNR.csv")

# %%
CorR_only_Answrs = (Ans.loc[Ans['Answer'] == '1 [YES] [correctly remembered]']) #1 [YES] [correctly remembered]

# %%
CorR_only_Answrs.shape
# Out:
# (138, 1)

# %%
#CorR_only_Answrs.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\CorR.csv")

# %%
WfR_only_Answrs =(Ans.loc[Ans['Answer'] == '0 [YES][WRONG:falsely remembered- FNSB]'])#0 [YES][WRONG:falsely remembered- FNSB]

# %%
WfR_only_Answrs.shape
# Out:
# (2, 1)

# %%
#WfR_only_Answrs.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\WfR.csv")

# %%
Mssd_only_Answrs = (Ans.loc[Ans['Answer'] == '0 missed trial'])

# %%
Mssd_only_Answrs.shape
# Out:
# (5, 1)

# %%
#Mssd_only_Answrs.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Mssd.csv")

# %%
CINFs_FBA = df_FBA[df_FBA['Answer'] == '1 [NO] [correctly identified as new face]']

# %%
CINFs_FBA.shape
# Out:
# (22, 3)

# %%
#CINFs_FBA.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\CINFs_FBA.csv")

# %%
CINFs_FBA.reset_index()
# Out:
#     index Faces            Button                                     Answer
# 0       0  158l  8 button pressed  1 [NO] [correctly identified as new face]
# 1       1  071r  8 button pressed  1 [NO] [correctly identified as new face]
# 2       3  008f  8 button pressed  1 [NO] [correctly identified as new face]
# 3       7  007r  8 button pressed  1 [NO] [correctly identified as new face]
# 4      11  045l  8 button pressed  1 [NO] [correctly identified as new face]
# 5      32  181l  8 button pressed  1 [NO] [correctly identified as new face]
# 6      44  198l  8 button pressed  1 [NO] [correctly identified as new face]
# 7      53  234l  8 button pressed  1 [NO] [correctly identified as new face]
# 8      54  070l  8 button pressed  1 [NO] [correctly identified as new face]
# 9      56  081l  8 button pressed  1 [NO] [correctly identified as new face]
# 10     66  150l  8 button pressed  1 [NO] [correctly identified as new face]
# ...

# %%
FsNR_FBA = df_FBA[df_FBA['Answer'] == '0 [NO][face not remembered]']

# %%
FsNR_FBA.shape
# Out:
# (22, 3)

# %%
#FsNR_FBA.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\FsNR_FBA.csv")

# %%
CorR_FBA = df_FBA[df_FBA['Answer'] == '1 [YES] [correctly remembered]']

# %%
CorR_FBA.shape
# Out:
# (138, 3)

# %%
#CorR_FBA.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\CorR_FBA.csv")

# %%
WfR_FBA = df_FBA[df_FBA['Answer'] == '0 [YES][WRONG:falsely remembered- FNSB]']

# %%
WfR_FBA.shape
# Out:
# (2, 3)

# %%
#WfR_FBA.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\WfR_FBA.csv")

# %%
Mssd_FBA = df_FBA[df_FBA['Answer'] == '0 missed trial']

# %%
Mssd_FBA.shape
# Out:
# (5, 3)

# %%
#Mssd_FBA.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Mssd_FBA.csv")

# %%
Num_of_yes = pd.concat([CorR_FBA, WfR_FBA], axis = 0)
#Num_of_yes.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Num_Of_Yes.csv")
Num_of_Nos = pd.concat([CINFs_FBA, FsNR_FBA], axis = 0)
#Num_of_Nos.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Num_Of_Nos.csv")

# %%
Num_of_yes.shape
# Out:
# (140, 3)

# %%
Num_of_Nos.shape
# Out:
# (44, 3)

# %%
num_Fc1L_prsntd = df_FBA[df_FBA['Faces'] == '233l']

# %%
num_Fc1L_prsntd.shape
# Out:
# (0, 3)

# %%
num_Fc1R_prsntd = df_FBA[df_FBA['Faces'] == '233r']

# %%
num_Fc1R_prsntd.shape
# Out:
# (0, 3)

# %%
num_Fc1F_prsntd = df_FBA[df_FBA['Faces'] == '233f']

# %%
num_Fc1F_prsntd.shape
# Out:
# (4, 3)

# %%
num_Fc1_prsntd = pd.concat([num_Fc1L_prsntd, num_Fc1R_prsntd, num_Fc1F_prsntd], axis = 0)

# %%
num_Fc1_prsntd.shape
# Out:
# (12, 3)

# %%
num_Fc1_prsntd_sorted = num_Fc1_prsntd.sort_index()

# %%
num_Fc1_prsntd_sorted
# Out:
#    Faces            Button                                     Answer
# 0   233f  8 button pressed  1 [NO] [correctly identified as new face]
# 12  233l  8 button pressed                0 [NO][face not remembered]
# 17  233f  8 button pressed                0 [NO][face not remembered]
# 27  233r  7 button pressed             1 [YES] [correctly remembered]
# 28  233l  7 button pressed             1 [YES] [correctly remembered]
# 35  233f  8 button pressed                0 [NO][face not remembered]
# 55  233l  7 button pressed             1 [YES] [correctly remembered]
# 65  233r  7 button pressed             1 [YES] [correctly remembered]
# 69  233r  7 button pressed             1 [YES] [correctly remembered]
# 80  233f  7 button pressed             1 [YES] [correctly remembered]
# 81  233l  7 button pressed             1 [YES] [correctly remembered]
# 86  233r  7 button pressed             1 [YES] [correctly remembered]

# %%
#num_Fc1_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc1.csv")
#num_Fc1_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc1.pkl")

# %%
#num_Fc2L_prsntd = df_FBA[df_FBA['Faces'] == '067l']

# %%
#num_Fc2L_prsntd.shape
# Out:
# (4, 3)

# %%
num_Fc2R_prsntd = df_FBA[df_FBA['Faces'] == '067r']

# %%
num_Fc2R_prsntd.shape
# Out:
# (4, 3)

# %%
num_Fc2F_prsntd = df_FBA[df_FBA['Faces'] == '067f']

# %%
num_Fc2F_prsntd.shape
# Out:
# (4, 3)

# %%
num_Fc2_prsntd = pd.concat([num_Fc2L_prsntd, num_Fc2R_prsntd, num_Fc2F_prsntd], axis = 0)

# %%
num_Fc2_prsntd.shape
# Out:
# (12, 3)

# %%
num_Fc2_prsntd_sorted = num_Fc2_prsntd.sort_index()

# %%
num_Fc2_prsntd_sorted
# Out:
#    Faces               Button                                     Answer
# 1   067l     8 button pressed  1 [NO] [correctly identified as new face]
# 2   067l     7 button pressed             1 [YES] [correctly remembered]
# 4   067f     8 button pressed                0 [NO][face not remembered]
# 5   067l     8 button pressed                0 [NO][face not remembered]
# 6   067f   button not pressed                             0 missed trial
# 15  067r     8 button pressed                0 [NO][face not remembered]
# 21  067r     7 button pressed             1 [YES] [correctly remembered]
# 22  067r     7 button pressed             1 [YES] [correctly remembered]
# 34  067f     7 button pressed             1 [YES] [correctly remembered]
# 37  067f     8 button pressed                0 [NO][face not remembered]
# 40  067r     8 button pressed                0 [NO][face not remembered]
# 42  067l     8 button pressed                0 [NO][face not remembered]

# %%
num_Fc2_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc2.csv")
num_Fc2_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc2.pkl")

# %%
num_Fc2_prsntd_NIndx = num_Fc2_prsntd_sorted.reset_index()

# %%
num_Fc2_prsntd_NIndx
# Out:
#     index Faces               Button  \
# 0       1  067l     8 button pressed
# 1       2  067l     7 button pressed
# 2       4  067f     8 button pressed
# 3       5  067l     8 button pressed
# 4       6  067f   button not pressed
# 5      15  067r     8 button pressed
# 6      21  067r     7 button pressed
# 7      22  067r     7 button pressed
# 8      34  067f     7 button pressed
# 9      37  067f     8 button pressed
# 10     40  067r     8 button pressed
# 11     42  067l     8 button pressed
#
#                                        Answer
# 0   1 [NO] [correctly identified as new face]
# 1              1 [YES] [correctly remembered]
# 2                 0 [NO][face not remembered]
# 3                 0 [NO][face not remembered]
# 4                              0 missed trial
# 5                 0 [NO][face not remembered]
# 6              1 [YES] [correctly remembered]
# 7              1 [YES] [correctly remembered]
# 8              1 [YES] [correctly remembered]
# ...

# %%
num_Fc3L_prsntd = df_FBA[df_FBA['Faces'] == '047l']
num_Fc3R_prsntd = df_FBA[df_FBA['Faces'] == '047r']
num_Fc3F_prsntd = df_FBA[df_FBA['Faces'] == '047f']
num_Fc3_prsntd = pd.concat([num_Fc3L_prsntd, num_Fc3R_prsntd, num_Fc3F_prsntd], axis = 0)
num_Fc3_prsntd_sorted = num_Fc3_prsntd.sort_index()
num_Fc3_prsntd_NIndx = num_Fc3_prsntd_sorted.reset_index()
num_Fc3_prsntd_NIndx
num_Fc3_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc3.csv")
num_Fc3_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc3.pkl")

# %%
num_Fc4L_prsntd = df_FBA[df_FBA['Faces'] == '286l']
num_Fc4R_prsntd = df_FBA[df_FBA['Faces'] == '286r']
num_Fc4F_prsntd = df_FBA[df_FBA['Faces'] == '286f']
num_Fc4_prsntd = pd.concat([num_Fc4L_prsntd, num_Fc4R_prsntd, num_Fc4F_prsntd], axis = 0)
num_Fc4_prsntd_sorted = num_Fc4_prsntd.sort_index()
num_Fc4_prsntd_NIndx = num_Fc4_prsntd_sorted.reset_index()
num_Fc4_prsntd_NIndx
num_Fc4_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc4.csv")
num_Fc4_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc4.pkl")

# %%
num_Fc5L_prsntd = df_FBA[df_FBA['Faces'] == '176l']
num_Fc5R_prsntd = df_FBA[df_FBA['Faces'] == '176r']
num_Fc5F_prsntd = df_FBA[df_FBA['Faces'] == '176f']
num_Fc5_prsntd = pd.concat([num_Fc5L_prsntd, num_Fc5R_prsntd, num_Fc5F_prsntd], axis = 0)
num_Fc5_prsntd_sorted = num_Fc5_prsntd.sort_index()
num_Fc5_prsntd_NIndx = num_Fc5_prsntd_sorted.reset_index()
num_Fc5_prsntd_NIndx
num_Fc5_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc5.csv")
num_Fc5_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc5.pkl")

# %%
num_Fc6L_prsntd = df_FBA[df_FBA['Faces'] == '203l']
num_Fc6R_prsntd = df_FBA[df_FBA['Faces'] == '203r']
num_Fc6F_prsntd = df_FBA[df_FBA['Faces'] == '203f']
num_Fc6_prsntd = pd.concat([num_Fc6L_prsntd, num_Fc6R_prsntd, num_Fc6F_prsntd], axis = 0)
num_Fc6_prsntd_sorted = num_Fc6_prsntd.sort_index()
num_Fc6_prsntd_NIndx = num_Fc6_prsntd_sorted.reset_index()
num_Fc6_prsntd_NIndx
num_Fc6_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc6.csv")
num_Fc6_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc6.pkl")

# %%
num_Fc7L_prsntd = df_FBA[df_FBA['Faces'] == '265l']
num_Fc7R_prsntd = df_FBA[df_FBA['Faces'] == '265r']
num_Fc7F_prsntd = df_FBA[df_FBA['Faces'] == '265f']
num_Fc7_prsntd = pd.concat([num_Fc7L_prsntd, num_Fc7R_prsntd, num_Fc7F_prsntd], axis = 0)
num_Fc7_prsntd_sorted = num_Fc7_prsntd.sort_index()
num_Fc7_prsntd_NIndx = num_Fc7_prsntd_sorted.reset_index()
num_Fc7_prsntd_NIndx
num_Fc7_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc7.csv")
num_Fc7_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc7.pkl")

# %%
num_Fc8L_prsntd = df_FBA[df_FBA['Faces'] == '054l']
num_Fc8R_prsntd = df_FBA[df_FBA['Faces'] == '054r']
num_Fc8F_prsntd = df_FBA[df_FBA['Faces'] == '054f']
num_Fc8_prsntd = pd.concat([num_Fc8L_prsntd, num_Fc8R_prsntd, num_Fc8F_prsntd], axis = 0)
num_Fc8_prsntd_sorted = num_Fc8_prsntd.sort_index()
num_Fc8_prsntd_NIndx = num_Fc8_prsntd_sorted.reset_index()
num_Fc8_prsntd_NIndx
num_Fc8_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc8.csv")
num_Fc8_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc8.pkl")

# %%
num_Fc9L_prsntd = df_FBA[df_FBA['Faces'] == '263l']
num_Fc9R_prsntd = df_FBA[df_FBA['Faces'] == '263r']
num_Fc9F_prsntd = df_FBA[df_FBA['Faces'] == '263f']
num_Fc9_prsntd = pd.concat([num_Fc9L_prsntd, num_Fc9R_prsntd, num_Fc9F_prsntd], axis = 0)
num_Fc9_prsntd_sorted = num_Fc9_prsntd.sort_index()
num_Fc9_prsntd_NIndx = num_Fc9_prsntd_sorted.reset_index()
num_Fc9_prsntd_NIndx
num_Fc9_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc9.csv")
num_Fc9_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc9.pkl")

# %%
num_Fc10L_prsntd = df_FBA[df_FBA['Faces'] == '100l']
num_Fc10R_prsntd = df_FBA[df_FBA['Faces'] == '100r']
num_Fc10F_prsntd = df_FBA[df_FBA['Faces'] == '100f']
num_Fc10_prsntd = pd.concat([num_Fc10L_prsntd, num_Fc10R_prsntd, num_Fc10F_prsntd], axis = 0)
num_Fc10_prsntd_sorted = num_Fc10_prsntd.sort_index()
num_Fc10_prsntd_NIndx = num_Fc10_prsntd_sorted.reset_index()
num_Fc10_prsntd_NIndx
num_Fc10_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc10.csv")
num_Fc10_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc10.pkl")

# %%
num_Fc11L_prsntd = df_FBA[df_FBA['Faces'] == '137l']
num_Fc11R_prsntd = df_FBA[df_FBA['Faces'] == '137r']
num_Fc11F_prsntd = df_FBA[df_FBA['Faces'] == '137f']
num_Fc11_prsntd = pd.concat([num_Fc11L_prsntd, num_Fc11R_prsntd, num_Fc11F_prsntd], axis = 0)
num_Fc11_prsntd_sorted = num_Fc11_prsntd.sort_index()
num_Fc11_prsntd_NIndx = num_Fc11_prsntd_sorted.reset_index()
num_Fc11_prsntd_NIndx
num_Fc11_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc11.csv")
num_Fc11_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc11.pkl")

# %%
num_Fc12L_prsntd = df_FBA[df_FBA['Faces'] == '253l']
num_Fc12R_prsntd = df_FBA[df_FBA['Faces'] == '253r']
num_Fc12F_prsntd = df_FBA[df_FBA['Faces'] == '253f']
num_Fc12_prsntd = pd.concat([num_Fc12L_prsntd, num_Fc12R_prsntd, num_Fc12F_prsntd], axis = 0)
num_Fc12_prsntd_sorted = num_Fc12_prsntd.sort_index()
num_Fc12_prsntd_NIndx = num_Fc12_prsntd_sorted.reset_index()
num_Fc12_prsntd_NIndx
num_Fc12_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc12.csv")
num_Fc12_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc12.pkl")

# %%
num_Fc13L_prsntd = df_FBA[df_FBA['Faces'] == '130l']
num_Fc13R_prsntd = df_FBA[df_FBA['Faces'] == '130r']
num_Fc13F_prsntd = df_FBA[df_FBA['Faces'] == '130f']
num_Fc13_prsntd = pd.concat([num_Fc13L_prsntd, num_Fc13R_prsntd, num_Fc13F_prsntd], axis = 0)
num_Fc13_prsntd_sorted = num_Fc13_prsntd.sort_index()
num_Fc13_prsntd_NIndx = num_Fc13_prsntd_sorted.reset_index()
num_Fc13_prsntd_NIndx
num_Fc13_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc13.csv")
num_Fc13_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc13.pkl")

# %%
num_Fc14L_prsntd = df_FBA[df_FBA['Faces'] == '003l']
num_Fc14R_prsntd = df_FBA[df_FBA['Faces'] == '003r']
num_Fc14F_prsntd = df_FBA[df_FBA['Faces'] == '003f']
num_Fc14_prsntd = pd.concat([num_Fc14L_prsntd, num_Fc14R_prsntd, num_Fc14F_prsntd], axis = 0)
num_Fc14_prsntd_sorted = num_Fc14_prsntd.sort_index()
num_Fc14_prsntd_NIndx = num_Fc14_prsntd_sorted.reset_index()
num_Fc14_prsntd_NIndx
num_Fc14_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc14.csv")
num_Fc14_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc14.pkl")

# %%
num_Fc15L_prsntd = df_FBA[df_FBA['Faces'] == '222l']
num_Fc15R_prsntd = df_FBA[df_FBA['Faces'] == '222r']
num_Fc15F_prsntd = df_FBA[df_FBA['Faces'] == '222f']
num_Fc15_prsntd = pd.concat([num_Fc15L_prsntd, num_Fc15R_prsntd, num_Fc15F_prsntd], axis = 0)
num_Fc15_prsntd_sorted = num_Fc15_prsntd.sort_index()
num_Fc15_prsntd_NIndx = num_Fc15_prsntd_sorted.reset_index()
num_Fc15_prsntd_NIndx
num_Fc15_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc15.csv")
num_Fc15_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc15.pkl")

# %%
num_Fc16L_prsntd = df_FBA[df_FBA['Faces'] == '098l']
num_Fc16R_prsntd = df_FBA[df_FBA['Faces'] == '098r']
num_Fc16F_prsntd = df_FBA[df_FBA['Faces'] == '098f']
num_Fc16_prsntd = pd.concat([num_Fc16L_prsntd, num_Fc16R_prsntd, num_Fc16F_prsntd], axis = 0)
num_Fc16_prsntd_sorted = num_Fc16_prsntd.sort_index()
num_Fc16_prsntd_NIndx = num_Fc16_prsntd_sorted.reset_index()
num_Fc16_prsntd_NIndx
num_Fc16_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc16.csv")
num_Fc16_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc16.pkl")

# %%
num_Fc17L_prsntd = df_FBA[df_FBA['Faces'] == '254l']
num_Fc17R_prsntd = df_FBA[df_FBA['Faces'] == '254r']
num_Fc17F_prsntd = df_FBA[df_FBA['Faces'] == '254f']
num_Fc17_prsntd = pd.concat([num_Fc17L_prsntd, num_Fc17R_prsntd, num_Fc17F_prsntd], axis = 0)
num_Fc17_prsntd_sorted = num_Fc17_prsntd.sort_index()
num_Fc17_prsntd_NIndx = num_Fc17_prsntd_sorted.reset_index()
num_Fc17_prsntd_NIndx
num_Fc17_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc17.csv")
num_Fc17_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc17.pkl")

# %%
num_Fc18L_prsntd = df_FBA[df_FBA['Faces'] == '_023']
num_Fc18R_prsntd = df_FBA[df_FBA['Faces'] == '_023']
num_Fc18F_prsntd = df_FBA[df_FBA['Faces'] == '_023']
num_Fc18_prsntd = pd.concat([num_Fc18L_prsntd, num_Fc18R_prsntd, num_Fc18F_prsntd], axis = 0)
num_Fc18_prsntd_sorted = num_Fc18_prsntd.sort_index()
num_Fc18_prsntd_NIndx = num_Fc18_prsntd_sorted.reset_index()
num_Fc18_prsntd_NIndx
num_Fc18_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc18.csv")
num_Fc18_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc18.pkl")

# %%
num_Fc19L_prsntd = df_FBA[df_FBA['Faces'] == '272l']
num_Fc19R_prsntd = df_FBA[df_FBA['Faces'] == '272r']
num_Fc19F_prsntd = df_FBA[df_FBA['Faces'] == '272f']
num_Fc19_prsntd = pd.concat([num_Fc19L_prsntd, num_Fc19R_prsntd, num_Fc19F_prsntd], axis = 0)
num_Fc19_prsntd_sorted = num_Fc19_prsntd.sort_index()
num_Fc19_prsntd_NIndx = num_Fc19_prsntd_sorted.reset_index()
num_Fc19_prsntd_NIndx
num_Fc19_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc19.csv")
num_Fc19_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc19.pkl")

# %%
num_Fc20L_prsntd = df_FBA[df_FBA['Faces'] == '224l']
num_Fc20R_prsntd = df_FBA[df_FBA['Faces'] == '224r']
num_Fc20F_prsntd = df_FBA[df_FBA['Faces'] == '224f']
num_Fc20_prsntd = pd.concat([num_Fc20L_prsntd, num_Fc20R_prsntd, num_Fc20F_prsntd], axis = 0)
num_Fc20_prsntd_sorted = num_Fc20_prsntd.sort_index()
num_Fc20_prsntd_NIndx = num_Fc20_prsntd_sorted.reset_index()
num_Fc20_prsntd_NIndx
num_Fc20_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc20.csv")
num_Fc20_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc20.pkl")

# %%
num_Fc21L_prsntd = df_FBA[df_FBA['Faces'] == '028l']
num_Fc21R_prsntd = df_FBA[df_FBA['Faces'] == '028r']
num_Fc21F_prsntd = df_FBA[df_FBA['Faces'] == '028f']
num_Fc21_prsntd = pd.concat([num_Fc21L_prsntd, num_Fc21R_prsntd, num_Fc21F_prsntd], axis = 0)
num_Fc21_prsntd_sorted = num_Fc21_prsntd.sort_index()
num_Fc21_prsntd_NIndx = num_Fc21_prsntd_sorted.reset_index()
num_Fc21_prsntd_NIndx
num_Fc21_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc21.csv")
num_Fc21_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc21.pkl")

# %%
num_Fc22L_prsntd = df_FBA[df_FBA['Faces'] == '279l']
num_Fc22R_prsntd = df_FBA[df_FBA['Faces'] == '279r']
num_Fc22F_prsntd = df_FBA[df_FBA['Faces'] == '279f']
num_Fc22_prsntd = pd.concat([num_Fc22L_prsntd, num_Fc22R_prsntd, num_Fc22F_prsntd], axis = 0)
num_Fc22_prsntd_sorted = num_Fc22_prsntd.sort_index()
num_Fc22_prsntd_NIndx = num_Fc22_prsntd_sorted.reset_index()
num_Fc22_prsntd_NIndx
num_Fc22_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc22.csv")
num_Fc22_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc22.pkl")

# %%
num_Fc23L_prsntd = df_FBA[df_FBA['Faces'] == '196l']
num_Fc23R_prsntd = df_FBA[df_FBA['Faces'] == '196r']
num_Fc23F_prsntd = df_FBA[df_FBA['Faces'] == '196f']
num_Fc23_prsntd = pd.concat([num_Fc23L_prsntd, num_Fc23R_prsntd, num_Fc23F_prsntd], axis = 0)
num_Fc23_prsntd_sorted = num_Fc23_prsntd.sort_index()
num_Fc23_prsntd_NIndx = num_Fc23_prsntd_sorted.reset_index()
num_Fc23_prsntd_NIndx
num_Fc23_prsntd_sorted.to_csv("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc23.csv")
num_Fc23_prsntd_sorted.to_pickle("C:\\Users\\Nestor\\Desktop\\FRAPPS\\ExperimentNstimulus\\out\\CSVs\\sub_001\\Fc23.pkl")
